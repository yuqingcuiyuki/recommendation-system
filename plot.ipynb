# %%
import matplotlib.pyplot as plt

# %%
beta=[0,00.25,0.5,0.75,1]
val=[0.000140545, 0.000139939, 0.000159766, 0.000187298, 0.000279743]
test=[3.37687e-05,3.61466e-05,3.88416e-05,4.51065e-05,6.32527e-05]
plt.plot(beta, val, label='validation MAP')
plt.plot(beta, test, label='test MAP')
plt.legend()
plt.xlabel('beta')

plt.show()

# %%
fraction=[0.25,0.5,0.75,1]
ALS=[76.45, 62.49,77.65, 87.26]
LightFM=[433.54, 518.98, 564.47, 599.40]
plt.plot(fraction, ALS, label='ALS')
plt.plot(fraction,LightFM, label='LightFM')
plt.legend()
plt.xlabel('fraction')
plt.ylabel('time (seconds)')
plt.show()
